# %%
print('a')
# Out:
# a

# %% [markdown]
# finite state machine
# nondeterministic finite automaton
# ## re
# re.search(pattern, string, flags=0)
#
# email address
# ..* equals to .+  one or more
# .*@..*
# .*@.+

# %%
import re
if re.search('.+@.+', 'malan@harvard.edu'):
    print('1Valid')
else:
    print("1Invalid")

if re.search('.+@.+', 'malan@harvard'):
    print('2Valid')
else:
    print("2Invalid")

if re.search('.+@.+.edu', 'malan@harvard'):
    print('3Valid')
else:
    print("3Invalid")


if re.search('.+@.+.edu', 'malan@.hhhedu'):
    print('4Valid')
else:
    print("4Invalid")

# raw string; backslash
if re.search(r'.+@.+\.edu', 'malan@2.edu333'):
    print('5Valid')
else:
    print("5Invalid")

if re.search(r'^.+@.+\.edu$', 'malan@@@malan.edu'):
    print('6Valid')
else:
    print("6Invalid")

if re.search(r'^[^@]+@[^@]+\.edu$', 'malan@@@malan.edu'):
    print('7Valid')
else:
    print("7Invalid")
# Out:
# 1Valid
# 2Valid
# 3Invalid
# 4Valid
# 5Valid
# 6Valid
# 7Invalid
# 8.1Invalid
# 8.2Invalid
# 8.3 word or space Valid

# %%
# raw string; backslash
if re.search(r'.+@.+\.edu', 'malan@2.edu333'):
    print('5Valid')
else:
    print("5Invalid")

if re.search(r'.+@.+\.edu', 'malan@2.EDU', re.IGNORECASE):
    print('5.2 Valid')
else:
    print("5.2 Invalid")
# Out:
# 5Valid
# 5.2 Valid

# %%
# word character
if re.search(r'^[a-zA-Z0-9_]+@[a-zA-Z0-9_]+\.edu$', 'malan@@@malan.edu'):
    print('8.1Valid')
else:
    print("8.1Invalid")

# charactor classes  alpha number underscore
# \w any word character  \W not word 
# \s space \S not space
# \d decimal \D not decimal 
if re.search(r'^\w+@\w+\.(edu|com|org)$', 'malan@@@malan.edu'):
    print('8.2Valid')
else:
    print("8.2Invalid")

if re.search(r'^(\w|\s)', 'hi friday'):
    print('8.3 word or space Valid')
else:
    print("8.3Invalid")

if re.search(r'^\w+@\w+\.(edu|com|org)$', 'malan@cs50.harvard.edu'):
    print('8.4 Valid')
elif re.search(r'^\w+@(\w|.)+\.(edu|com|org)$', 'malan@cs50.harvard.edu'):
    print("8.4 group match")
else:
    pass

# ? 0 or 1  repetition
if re.search(r'^\w+@(\.?\w)+', 'malan@cs50.harvard.edu'):
    print('8.5 Valid')
# Out:
# 8.1Invalid
# 8.2Invalid
# 8.3 word or space Valid
# 8.4 group match
# 8.5 Valid

# %%
# format capturing groups
import re
name1 = 'Malan,          David'
# :=  walrus operator
if matches := re.search(r"^(.+), *(.+)", name1):
# if matches:
    last, first = matches.groups()
    name1 = f"{first} {last}"
print(f"hello, {name1}")
# Out:
# hello, David Malan

# %%
# re.sub(pattern, repl, strings, counts, flags)  substitution

url = 'https://twitter.com/davidjmalan'
username = re.sub(r"https://twitter.com/", "", url)
print(f"username1: {username}")

url2 = 'http://www.twitter.com/davidjmalan'
username2 = re.sub(r"^(https?://)?(www\.)?twitter\.com/", "", url2)
print(f"username2: {username2}")

url3 = '  twitter.com/davidjmalan'
username3 = re.sub(r"^(https?://)?(www\.)?twitter\.com/", "", url2)
print(f"username3: {username3}")

url4 = 'http://www.twitter.com/davidjmalan'
if matches := re.search(r"^https?://(?:www\.)?twitter\.com/(.+)$", url4, re.IGNORECASE):
    print(f"username4: ", matches.group(1))
# Out:
# username1: davidjmalan
# username2: davidjmalan
# username3: davidjmalan
# username4:  davidjmalan
# Bad pipe message: %s [b"}\x90\xecK'\xb5x\xf3\xd4\x8aK\xc23\x17\x85\x030=\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008"]
# Bad pipe message: %s [b'%\xa2\xc5G\xe3\x07\xefR.\r\xc3U\xe2>g\xf6I\x91\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04']
# Bad pipe message: %s [b'\x01\x02']
# Bad pipe message: %s [b'\x19dIxC\xe7#\xd9@\xe8\xba\x12\xaett\xa8']
# Bad pipe message: %s [b'\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00', b'\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01']
# Bad pipe message: %s [b'\x14\xd8\x7f\x98\xc4\x0e\x84\x82\xb9TO\xc2\xa4\tLf\x1c\xb7\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00']
# Bad pipe message: %s [b'\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01\x15']
# Bad pipe message: %s [b'\x04\xd3W\xab0q\xe8\x12N\xbb\xf6:']
# Bad pipe message: %s [b'\xa3\xd63\xf3\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00']
# Bad pipe message: %s [b'A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'i\xca\x1c\xa7C4\xf5\xf6Zb\x93z\x98f\xbb\xb2\x9dH\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00', b'\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12']
# Bad pipe message: %s [b'\xea"\xd0\x99\xcb\xa9@^\xcacML/\xac\x19\x9a\xff\xac\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00', b"j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00"]
# Bad pipe message: %s [b'l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00;\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00']
# Bad pipe message: %s [b'\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00']
